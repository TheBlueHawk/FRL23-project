# %%
import json
import pandas as pd

def read_json_file(file_path):
    data = []
    with open(file_path, 'r') as file:
        for line in file:
            json_obj = json.loads(line)
            data.append(json_obj)
    return data

# %%
json_path = "/cluster/scratch/mullec/FoRL/FRL23-project/dreamerv3/logdir/cartpole_default_settings/metrics.jsonl"

metrics = read_json_file(json_path)

metrics_df = pd.json_normalize(metrics)

# Print the DataFrame
for col in metrics_df.columns:
    print(col)
# Out:
# step
# episode/length
# episode/score
# episode/reward_rate
# train/action_mag
# train/action_max
# train/action_mean
# train/action_min
# train/action_std
# train/actor_opt_actor_opt_grad_overflow
# train/actor_opt_actor_opt_grad_scale
# train/actor_opt_grad_norm
# train/actor_opt_grad_steps
# train/actor_opt_loss
# train/adv_mag
# train/adv_max
# train/adv_mean
# train/adv_min
# train/adv_std
# train/cont_avg
# train/cont_loss_mean
# train/cont_loss_std
# train/cont_neg_acc
# train/cont_neg_loss
# train/cont_pos_acc
# train/cont_pos_loss
# train/cont_pred
# train/cont_rate
# train/dyn_loss_mean
# train/dyn_loss_std
# train/extr_critic_critic_opt_critic_opt_grad_overflow
# train/extr_critic_critic_opt_critic_opt_grad_scale
# train/extr_critic_critic_opt_grad_norm
# train/extr_critic_critic_opt_grad_steps
# train/extr_critic_critic_opt_loss
# train/extr_critic_mag
# train/extr_critic_max
# train/extr_critic_mean
# train/extr_critic_min
# train/extr_critic_std
# train/extr_return_normed_mag
# train/extr_return_normed_max
# train/extr_return_normed_mean
# train/extr_return_normed_min
# train/extr_return_normed_std
# train/extr_return_rate
# train/extr_return_raw_mag
# train/extr_return_raw_max
# train/extr_return_raw_mean
# train/extr_return_raw_min
# train/extr_return_raw_std
# train/extr_reward_mag
# train/extr_reward_max
# train/extr_reward_mean
# train/extr_reward_min
# train/extr_reward_std
# train/model_loss_mean
# train/model_loss_std
# train/model_opt_grad_norm
# train/model_opt_grad_steps
# train/model_opt_loss
# train/model_opt_model_opt_grad_overflow
# train/model_opt_model_opt_grad_scale
# train/policy_entropy_mag
# train/policy_entropy_max
# train/policy_entropy_mean
# train/policy_entropy_min
# train/policy_entropy_std
# train/policy_logprob_mag
# train/policy_logprob_max
# train/policy_logprob_mean
# train/policy_logprob_min
# train/policy_logprob_std
# train/policy_randomness_mag
# train/policy_randomness_max
# train/policy_randomness_mean
# train/policy_randomness_min
# train/policy_randomness_std
# train/post_ent_mag
# train/post_ent_max
# train/post_ent_mean
# train/post_ent_min
# train/post_ent_std
# train/prior_ent_mag
# train/prior_ent_max
# train/prior_ent_mean
# train/prior_ent_min
# train/prior_ent_std
# train/rep_loss_mean
# train/rep_loss_std
# train/reward_avg
# train/reward_loss_mean
# train/reward_loss_std
# train/reward_max_data
# train/reward_max_pred
# train/reward_neg_acc
# train/reward_neg_loss
# train/reward_pos_acc
# train/reward_pos_loss
# train/reward_pred
# train/reward_rate
# train/state_vec_loss_mean
# train/state_vec_loss_std
# train/params_agent/wm/model_opt
# train/params_agent/task_behavior/critic/critic_opt
# train/params_agent/task_behavior/ac/actor_opt
# report/cont_avg
# report/cont_loss_mean
# report/cont_loss_std
# report/cont_neg_acc
# report/cont_neg_loss
# report/cont_pos_acc
# report/cont_pos_loss
# report/cont_pred
# report/cont_rate
# report/dyn_loss_mean
# report/dyn_loss_std
# report/model_loss_mean
# report/model_loss_std
# report/post_ent_mag
# report/post_ent_max
# report/post_ent_mean
# report/post_ent_min
# report/post_ent_std
# report/prior_ent_mag
# report/prior_ent_max
# report/prior_ent_mean
# report/prior_ent_min
# report/prior_ent_std
# report/rep_loss_mean
# report/rep_loss_std
# report/reward_avg
# report/reward_loss_mean
# report/reward_loss_std
# report/reward_max_data
# report/reward_max_pred
# report/reward_neg_acc
# report/reward_neg_loss
# report/reward_pos_acc
# report/reward_pos_loss
# report/reward_pred
# report/reward_rate
# report/state_vec_loss_mean
# report/state_vec_loss_std
# eval/cont_avg
# eval/cont_loss_mean
# eval/cont_loss_std
# eval/cont_neg_acc
# eval/cont_neg_loss
# eval/cont_pos_acc
# eval/cont_pos_loss
# eval/cont_pred
# eval/cont_rate
# eval/dyn_loss_mean
# eval/dyn_loss_std
# eval/model_loss_mean
# eval/model_loss_std
# eval/post_ent_mag
# eval/post_ent_max
# eval/post_ent_mean
# eval/post_ent_min
# eval/post_ent_std
# eval/prior_ent_mag
# eval/prior_ent_max
# eval/prior_ent_mean
# eval/prior_ent_min
# eval/prior_ent_std
# eval/rep_loss_mean
# eval/rep_loss_std
# eval/reward_avg
# eval/reward_loss_mean
# eval/reward_loss_std
# eval/reward_max_data
# eval/reward_max_pred
# eval/reward_neg_acc
# eval/reward_neg_loss
# eval/reward_pos_acc
# eval/reward_pos_loss
# eval/reward_pred
# eval/reward_rate
# eval/state_vec_loss_mean
# eval/state_vec_loss_std
# replay/size
# replay/inserts
# replay/samples
# replay/insert_wait_avg
# replay/insert_wait_frac
# replay/sample_wait_avg
# replay/sample_wait_frac
# eval_replay/size
# eval_replay/inserts
# eval_replay/samples
# eval_replay/insert_wait_avg
# eval_replay/insert_wait_frac
# eval_replay/sample_wait_avg
# eval_replay/sample_wait_frac
# timer/duration
# timer/env.step_count
# timer/env.step_total
# timer/env.step_frac
# timer/env.step_avg
# timer/env.step_min
# timer/env.step_max
# timer/replay._sample_count
# timer/replay._sample_total
# timer/replay._sample_frac
# timer/replay._sample_avg
# timer/replay._sample_min
# timer/replay._sample_max
# timer/agent.save_count
# timer/agent.save_total
# timer/agent.save_frac
# timer/agent.save_avg
# timer/agent.save_min
# timer/agent.save_max
# timer/agent.policy_count
# timer/agent.policy_total
# timer/agent.policy_frac
# timer/agent.policy_avg
# timer/agent.policy_min
# timer/agent.policy_max
# timer/dataset_train_count
# timer/dataset_train_total
# timer/dataset_train_frac
# timer/dataset_train_avg
# timer/dataset_train_min
# timer/dataset_train_max
# timer/agent.train_count
# timer/agent.train_total
# timer/agent.train_frac
# timer/agent.train_avg
# timer/agent.train_min
# timer/agent.train_max
# timer/agent.report_count
# timer/agent.report_total
# timer/agent.report_frac
# timer/agent.report_avg
# timer/agent.report_min
# timer/agent.report_max
# timer/dataset_eval_count
# timer/dataset_eval_total
# timer/dataset_eval_frac
# timer/dataset_eval_avg
# timer/dataset_eval_min
# timer/dataset_eval_max
# train_stats/mean_log_entropy
# fps

# %%
episode_df = metrics_df[["episode/length", "episode/score", "episode/reward_rate"]]
episode_df.loc[:, "episode/scaled_score"] = episode_df["episode/score"] - episode_df["episode/length"] * cost_per_observation
episode_df['step'] = episode_df['episode/length'].cumsum().shift(fill_value=0)
# Out:
# /tmp/ipykernel_23717/766913412.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   episode_df.loc[:, "episode/scaled_score"] = episode_df["episode/score"] - episode_df["episode/length"] * cost_per_observation
# /tmp/ipykernel_23717/766913412.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   episode_df['step'] = episode_df['episode/length'].cumsum().shift(fill_value=0)

# %%
import matplotlib.pyplot as plt

episode_df_no_na = episode_df.dropna(how='any', subset=['episode/scaled_score', 'step'])

# Calculate the moving average using a window size of 10
episode_df_no_na['smoothed_scaled_score'] = episode_df_no_na['episode/scaled_score'].rolling(window=20, min_periods=1).mean()

# Plot the original data points and the smoothing line
plt.plot(episode_df_no_na['step'], episode_df_no_na['episode/scaled_score'], marker='o', linestyle='-', color='b', linewidth=0.2, markersize=0)
plt.plot(episode_df_no_na['step'], episode_df_no_na['smoothed_scaled_score'], linestyle='-', color='r', linewidth=1)
plt.xlabel('Training Steps')
plt.ylabel('Discounted Returns')
plt.title('Discounted Returns vs. Steps')
plt.legend(['Original', 'Smoothed'])
plt.show()
# Out:
# /tmp/ipykernel_23717/3948331463.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   episode_df_no_na['smoothed_scaled_score'] = episode_df_no_na['episode/scaled_score'].rolling(window=20, min_periods=1).mean()

# %%
episode_df_no_na = episode_df.dropna(how='any', subset=['episode/score', 'step'])

# Calculate the moving average using a window size of 10
episode_df_no_na['smoothed_score'] = episode_df_no_na['episode/score'].rolling(window=20, min_periods=1).mean()

# Plot the original data points and the smoothing line
plt.plot(episode_df_no_na['step'], episode_df_no_na['episode/score'], marker='o', linestyle='-', color='b', linewidth=0.2, markersize=0)
plt.plot(episode_df_no_na['step'], episode_df_no_na['smoothed_score'], linestyle='-', color='r', linewidth=1)
plt.xlabel('Training Steps')
plt.ylabel('Returns')
plt.title('Returns vs. Steps')
plt.legend(['Original', 'Smoothed'])
plt.show()
# Out:
# /tmp/ipykernel_23717/982774895.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   episode_df_no_na['smoothed_score'] = episode_df_no_na['episode/score'].rolling(window=20, min_periods=1).mean()

# %%
METRIC = "train/prior_ent_mean"
ROLLING_WINDOW = 3


metrics_df_no_na = metrics_df.dropna(how='any', subset=[METRIC, 'step'])

# Calculate the moving average using a window size of 10
metrics_df_no_na['smoothed_' + METRIC] = metrics_df_no_na[METRIC].rolling(window=ROLLING_WINDOW, min_periods=1).mean()

# Plot the original data points and the smoothing line
plt.plot(metrics_df_no_na['step'], metrics_df_no_na[METRIC], marker='o', linestyle='-', color='b', linewidth=0.2, markersize=0)
plt.plot(metrics_df_no_na['step'], metrics_df_no_na['smoothed_' + METRIC], linestyle='-', color='r', linewidth=1)
plt.xlabel('Training Steps')
plt.ylabel(METRIC)
plt.title(METRIC + " vs. Steps")
plt.legend(['Original', 'Smoothed'])
plt.show()
# Out:
# /tmp/ipykernel_23717/169501450.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metrics_df_no_na['smoothed_' + METRIC] = metrics_df_no_na[METRIC].rolling(window=ROLLING_WINDOW, min_periods=1).mean()
